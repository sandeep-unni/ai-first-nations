# %%
from deepforest import main

m = main.deepforest()
m.load_model(model_name="weecology/deepforest-tree")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from deepforest import main
#       3 m = main.deepforest()
#       4 m.load_model(model_name="weecology/deepforest-tree")
#
# ModuleNotFoundError: No module named 'deepforest'

# %%
pip install deepforest
